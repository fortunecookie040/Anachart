# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("META_NVDA_Extract 1.csv")
df.head()
# Out:
#          date        company_Name ticker         broker       analytst  \
# 0  10/24/2023  Meta Platforms Inc   META            NaN  AARON KESSLER
# 1    2/2/2023  Meta Platforms Inc   META  RAYMOND JAMES  AARON KESSLER
# 2   3/15/2023  Meta Platforms Inc   META  RAYMOND JAMES  AARON KESSLER
# 3   4/27/2023  Meta Platforms Inc   META  RAYMOND JAMES  AARON KESSLER
# 4   8/29/2024         Nvidia Corp   NVDA    WELLS FARGO   AARON RAKERS
#
#                    rating_before                   rating_after  \
# 0  Buy                            Buy
# 1                                 OUTPERFORM
# 2  Outperform                     Outperform
# 3                                 OUTPERFORM
# 4                                 OVERWEIGHT
#
#    price_target_before  price_target_after
# 0                365.0               365.0
# 1                171.0               220.0
# 2                238.0               238.0
# 3                238.0               287.0
# 4                155.0               165.0

# %%
df["date"] = pd.to_datetime(df["date"]).dt.date
df_1 = DATA.groupby(["date", "ticker"]).agg(price_prediction = ("price_target_after", "mean"))
df_1
# Out:
#                   price_prediction
# date      ticker
# 1/10/2025 META               712.0
# 1/11/2023 NVDA                22.0
# 1/13/2025 META               660.0
# 1/14/2025 META               668.0
# 1/17/2024 META               415.0
# ...                            ...
# 9/28/2023 META               384.2
# 9/30/2024 META               660.0
# 9/5/2024  META               660.0
#           NVDA               165.0
# 9/8/2025  NVDA               200.0
#
# [276 rows x 1 columns]

# %%
df_2 = df_1.sort_values("date")
df_2
sns.relplot(data = df_2, x = "date", y = "price_prediction", kind = "line", hue = "ticker", aspect = 3)
plt.xticks(rotation = 90)
plt.title("Meta vs Nvidia Price Predictions")
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_locator(mdates.YearLocator(base=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_310/581435780.py in ?()
#       2 df_2
#       3 sns.relplot(data = df_2, x = "date", y = "price_prediction", kind = "line", hue = "ticker", aspect = 3)
#       4 plt.xticks(rotation = 90)
#       5 plt.title("Meta vs Nvidia Price Predictions")
# ----> 6 ax = df_2.ax
#       7 ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
#       8 ax.xaxis.set_major_locator(mdates.YearLocator(base=2))
#       9 ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
#
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ax'
